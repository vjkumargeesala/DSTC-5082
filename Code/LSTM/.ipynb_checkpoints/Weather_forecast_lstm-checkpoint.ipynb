# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# df = pd.read_csv('/content/DFW_weather.csv')
df = pd.read_csv('/Users/vj/Jupyter Notebook/DSTC-5082/Data/FinalDataset.csv')
# df = pd.read_csv('/content/embedded_weather_data 1.csv')
print(df.head())
print(len(df))
# Out:
#    Unnamed: 0             datetime  dew_point_C  clouds_all  visibility  \
# 0           0  2001-01-01 00:00:00        -2.50         100      3200.0
# 1           1  2001-01-01 01:00:00        -2.99         100     10000.0
# 2           2  2001-01-01 02:00:00        -3.02         100     10000.0
# 3           3  2001-01-01 03:00:00        -3.77         100     10000.0
# 4           4  2001-01-01 04:00:00        -3.45         100     10000.0
#
#    Longwave_Irradiance_Wm2  Shortwave_Irradiance_Wm2  pressure_kPa  humidity  \
# 0                   264.88                       0.0        101.94     100.0
# 1                   253.45                       0.0        101.94      97.5
# 2                   249.07                       0.0        101.96      97.5
# 3                   261.33                       0.0        102.01      96.0
# 4                   255.15                       0.0        102.06      97.5
#
#    wind_speed  rain_1h  Temp
# 0        2.92     0.02 -5.62
# 1        2.96     0.01 -5.85
# 2        2.50     0.01 -5.99
# 3        2.31     0.02 -6.11
# 4        2.14     0.06 -6.40
# 210384

# %%
# Convert datetime column to datetime format (no need to remove ' UTC' or parse a timezone)
df['datetime'] = pd.to_datetime(df['datetime'], format='%Y-%m-%d %H:%M:%S')

# Set datetime as index
df.set_index('datetime', inplace=True)

print(len(df))
# Out:
# 210384

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'dew_point_C', 'clouds_all', 'visibility',
#        'Longwave_Irradiance_Wm2', 'Shortwave_Irradiance_Wm2', 'pressure_kPa',
#        'humidity', 'wind_speed', 'rain_1h', 'Temp'],
#       dtype='object')

# %%
temp = df['Temp']
temp.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
import numpy as np

def df_to_X_y(df, target_col, window_size):
    feature_cols = ['Temp', 'dew_point_C', 'wind_speed', 'pressure_kPa', 'humidity']

    df_as_np = df[feature_cols].to_numpy()
    target_np = df[target_col].to_numpy()

    X, y = [], []
    for i in range(len(df_as_np) - window_size):
        X.append(df_as_np[i:(i + window_size)])
        y.append(target_np[i + window_size])

    return np.array(X), np.array(y)

# %%
window_size = 24
X, y = df_to_X_y(df, 'Temp', window_size)
X.shape, y.shape
# Out:
# ((210360, 24, 5), (210360,))

# %%
X_train,y_train = X[:200000],y[:200000]
X_test,y_test = X[200000:250000],y[200000:250000]
X_valid,y_valid = X[250000:],y[250000:]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((window_size , 5)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 64)             │        17,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,449 (72.07 KB)
#  Trainable params: 18,449 (72.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()], optimizer=Adam(learning_rate=0.0001))
model1.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=10)

model1.save('model1.keras')
# Out:
# Epoch 1/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 79.3041 - root_mean_squared_error: 8.1040
# Epoch 2/10
#   58/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.4563 - root_mean_squared_error: 0.6744
# /opt/anaconda3/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.4141 - root_mean_squared_error: 0.6433
# Epoch 3/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.3191 - root_mean_squared_error: 0.5649
# Epoch 4/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.2940 - root_mean_squared_error: 0.5421
# Epoch 5/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.2788 - root_mean_squared_error: 0.5280
# Epoch 6/10
#   60/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.2615 - root_mean_squared_error: 0.5106
# 2025-04-19 15:19:32.204414: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.2735 - root_mean_squared_error: 0.5230
# Epoch 7/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.2643 - root_mean_squared_error: 0.5141
# Epoch 8/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.2643 - root_mean_squared_error: 0.5141
# Epoch 9/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.2612 - root_mean_squared_error: 0.5110
# Epoch 10/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.2583 - root_mean_squared_error: 0.5082

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1.keras')

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
# Out:
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(test_results['Test Predictions'][:1000], label='Test Predictions')
plt.plot(test_results['Actuals'][:1000], label='Actuals')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Evaluate on test data
mse = mean_squared_error(y_test, test_predictions)
mae = mean_absolute_error(y_test, test_predictions)
r2 = r2_score(y_test, test_predictions)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R²: {r2:.4f}")
# Out:
# Test MSE: 0.2441
# Test MAE: 0.3728
# Test R²: 0.9971

# %%
# Start with the last known 24-hour window
input_seq = X_test[-1]  # Shape: (24, 5)
future_preds = []

for _ in range(24):  # Predict next 24 hours
    pred = model1.predict(input_seq.reshape(1, 24, 5), verbose=0).flatten()[0]
    future_preds.append(pred)

    # Shift the window and replace only the temperature in the last row
    next_input = np.roll(input_seq, -1, axis=0)
    next_input[-1, 0] = pred  # Replace temperature only
    input_seq = next_input

# Get actual temperatures for comparison
actual_temps = y_test[-24:]

# Plot future predictions vs actuals
plt.figure(figsize=(10, 5))
plt.plot(future_preds, marker='o', label='24-hour Forecasted Temps')
plt.plot(actual_temps, marker='x', label='Actual Temps')
plt.title('Recursive 24-hour Temperature Forecast vs Actual')
plt.xlabel('Hour Ahead')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Start with the last known 24-hour window
input_seq = X_test[-1]  # Shape: (24, 5)
future_preds = []

# Use actual temps from y_test to update the window
actual_temps = y_test[-24:]

for i in range(24):  # Predict next 24 hours
    pred = model1.predict(input_seq.reshape(1, 24, 5), verbose=0).flatten()[0]
    future_preds.append(pred)

    # Shift the window and replace temperature with ACTUAL temp
    next_input = np.roll(input_seq, -1, axis=0)
    next_input[-1, 0] = actual_temps[i]  # Use actual temperature, not predicted
    input_seq = next_input

# Plot predicted vs actual
plt.figure(figsize=(10, 5))
plt.plot(future_preds, marker='o', label='24-hour Forecasted Temps')
plt.plot(actual_temps, marker='x', label='Actual Temps')
plt.title('24-hour Forecast (Window Updated with Actual Temps)')
plt.xlabel('Hour Ahead')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

def df_to_X_y(df, target_col, window_size):
    feature_cols = ['Temp', 'dew_point_C', 'wind_speed', 'pressure_kPa', 'humidity']

    df_as_np = df[feature_cols].to_numpy()
    target_np = df[target_col].to_numpy()

    X, y = [], []
    for i in range(len(df_as_np) - window_size):
        X.append(df_as_np[i:(i + window_size)])
        y.append(target_np[i + window_size])

    return np.array(X), np.array(y)

# %%
target_cols = [ 'humidity']
window_size = 24
X, y = df_to_X_y(df, target_cols, window_size)

X_train, y_train = X[:200000], y[:200000]
X_test, y_test = X[200000:250000], y[200000:250000]
X_valid, y_valid = X[250000:], y[250000:]

# %%
model1 = Sequential()
model1.add(InputLayer((window_size, 5)))
model1.add(LSTM(128, return_sequences=True))
model1.add(Dropout(0.2))
model1.add(LSTM(64))
model1.add(Dense(32, activation='relu'))
model1.add(Dense(1, activation='linear'))

model1.compile(
    loss=MeanSquaredError(),
    optimizer=Adam(learning_rate=0.001),
    metrics=[RootMeanSquaredError(), 'mae']
)

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5)

model1.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=10,
    callbacks=[early_stop, lr_schedule]
)
model1.save('modelhumidity.keras')
# Out:
# Epoch 1/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 72s 11ms/step - loss: 320.3222 - mae: 9.2101 - root_mean_squared_error: 15.2888 - learning_rate: 0.0010
# Epoch 2/10
#   14/6250 ━━━━━━━━━━━━━━━━━━━━ 1:17 12ms/step - loss: 12.0399 - mae: 2.5864 - root_mean_squared_error: 3.4532
# /opt/anaconda3/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,root_mean_squared_error
#   current = self.get_monitor_value(logs)
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,root_mean_squared_error,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 71s 11ms/step - loss: 11.4441 - mae: 2.4951 - root_mean_squared_error: 3.3827 - learning_rate: 0.0010
# Epoch 3/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 70s 11ms/step - loss: 10.6493 - mae: 2.4068 - root_mean_squared_error: 3.2632 - learning_rate: 0.0010
# Epoch 4/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 71s 11ms/step - loss: 10.2621 - mae: 2.3552 - root_mean_squared_error: 3.2034 - learning_rate: 0.0010
# Epoch 5/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 71s 11ms/step - loss: 9.9734 - mae: 2.3156 - root_mean_squared_error: 3.1579 - learning_rate: 0.0010
# Epoch 6/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 71s 11ms/step - loss: 9.6948 - mae: 2.2835 - root_mean_squared_error: 3.1136 - learning_rate: 0.0010
# Epoch 7/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 72s 11ms/step - loss: 9.5928 - mae: 2.2717 - root_mean_squared_error: 3.0972 - learning_rate: 0.0010
# Epoch 8/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 72s 12ms/step - loss: 9.4067 - mae: 2.2467 - root_mean_squared_error: 3.0670 - learning_rate: 0.0010
# Epoch 9/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 74s 12ms/step - loss: 9.4199 - mae: 2.2465 - root_mean_squared_error: 3.0689 - learning_rate: 0.0010
# Epoch 10/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 115s 18ms/step - loss: 9.2664 - mae: 2.2228 - root_mean_squared_error: 3.0440 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import load_model
modelhumidity = load_model('modelhumidity.keras')

# %%
test_predictions = modelhumidity.predict(X_test).flatten()
print(test_predictions)
actuals = y_test.flatten() if len(y_test.shape) > 1 else y_test

test_results = pd.DataFrame(data={
    'Test Predictions': test_predictions,
    'Actuals': actuals
})
# Out:
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [87.72468 85.35318 81.48227 ... 67.36987 68.2353  70.66934]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(test_results['Test Predictions'][:1000], label='Test Predictions')
plt.plot(test_results['Actuals'][:1000], label='Actuals')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Evaluate on test data
mse = mean_squared_error(y_test, test_predictions)
mae = mean_absolute_error(y_test, test_predictions)
r2 = r2_score(y_test, test_predictions)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R²: {r2:.4f}")
# Out:
# Test MSE: 8.9413
# Test MAE: 2.1138
# Test R²: 0.9564

# %%
input_seq = X_test[-2]
future_preds = []

for _ in range(48):
    pred = modelhumidity.predict(input_seq.reshape(1, 24, 5), verbose=0).flatten()[0]
    future_preds.append(pred)

    # Shift the window and replace only the temperature in the last row
    next_input = np.roll(input_seq, -1, axis=0)
    next_input[-1, 0] = pred  # Replace temperature only
    input_seq = next_input

# Get actual temperatures for comparison
actual_temps = y_test[-48:]

# Plot future predictions vs actuals
plt.figure(figsize=(10, 5))
plt.plot(future_preds, marker='o', label='24-hour Forecasted Humidity')
plt.plot(actual_temps, marker='x', label='Actual Humidity')
plt.title('Recursive 24-hour Humidity Forecast vs Actual')
plt.xlabel('Hour Ahead')
plt.ylabel('Humidity')
plt.legend()
plt.grid(True)
plt.show()
